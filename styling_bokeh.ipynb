# %% [markdown]
# #  Assigning styling to Bokeh

# %%
import numpy as np
import pandas as pd
import bokeh.io
import bokeh.models
import bokeh.palettes
import bokeh.plotting
import seaborn as sns
sns.set_palette('colorblind')
bokeh.io.output_notebook()
# bokeh.io.curdoc().theme = bokeh.themes.Theme('../../plot_theme.yaml')
z = bokeh.document.Theme('plot_theme.yaml')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1a64e21b-19d2-4613-a47e-eca2f642879d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# I'm interesteed to shifting to bokeh for all my plotting needs, but I want to set up a figure handler that will allow me to plot them as I normally

# %% [markdown]
# The dataset I will use is the simulated dilution data from June 17th.

# %% [markdown]
# ## Making an example plot.

# %%
props = {'background_fill_color': '#E3DCD0',
        'outline_line_color' : None}

# %%
# Make a bokeh figure axis. 
p = bokeh.plotting.figure()
p.background_fill_color='#E3DCD0'
p.xgrid.grid_line_color = '#FFFFFF'
p.ygrid.grid_line_color = '#FFFFFF'
p.xgrid.grid_line_dash = 'dotted'
p.ygrid.grid_line_dash = 'dotted'
p.xgrid.grid_line_width = 2
p.ygrid.grid_line_width = 2
p.axis.minor_tick_line_color = None
p.axis.major_tick_line_color = None
p.axis.axis_line_color = None
p.axis.axis_label_text_font = 'Lucida Sans Unicode'
p.axis.axis_label_text_font_style = 'normal'
p.axis.axis_label_text_font_size = '13pt'
p.axis.axis_label_text_color = '#3c3c3c'
p.axis.axis_label_standoff = 2

# Now for the actual plotting. 
x = np.random.normal(size=5000)
y = np.random.normal(size=5000)
p.circle(x, y, size=7)
p.c

p.xaxis.axis_label= 'log summed intensity '
p.yaxis.axis_label= 'log squared difference'

bokeh.io.show(p)
# Specify and plot the glyhs
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4a150d3b-2f44-4d9d-b896-df6a96b25038"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4a150d3b-2f44-4d9d-b896-df6a96b25038");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4a150d3b-2f44-4d9d-b896-df6a96b25038");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4a150d3b-2f44-4d9d-b896-df6a96b25038' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"75f2196b-5548-4c31-ab68-77b34d313417":{"roots":{"references":[{"attributes":{},"id":"ced7fe11-a6eb-4f9e-aaa0-f1a96ddae6b5","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":7},"x":{"field":"x"},"y":{"field":"y"}},"id":"94e61f31-b927-49ca-86fa-eb3720cb05ff","type":"Circle"},{"attributes":{},"id":"a34d508d-6bf3-466f-9e4b-22266effec5e","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"103eaf33-05be-4c5f-9c08-98687e3ada87","type":"Title"},{"attributes":{"overlay":{"id":"05e8c402-b18d-42da-8e10-bfe3bb7a0716","type":"BoxAnnotation"},"plot":{"id":"0f9b44ab-483e-4ad5-b35f-b16c78be0356","subtype":"Figure","type":"Plot"}},"id":"13f196f4-39c5-4bb1-b20b-5cf85fcb3a98","type":"BoxZoomTool"},{"attributes":{},"id":"338a2f25-0572-4861-b976-f29c37aefd8e","type":"BasicTicker"},{"attributes":{},"id":"789e608b-8ebb-4fc0-b945-bd23c866feae","type":"LinearScale"},{"attributes":{"plot":{"id":"0f9b44ab-483e-4ad5-b35f-b16c78be0356","subtype":"Figure","type":"Plot"}},"id":"74a9e306-a5ae-4b59-a394-f32ae7767eec","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"74a9e306-a5ae-4b59-a394-f32ae7767eec","type":"PanTool"},{"id":"1906d6a5-5ee8-48da-906a-d0b73bcee3dc","type":"WheelZoomTool"},{"id":"13f196f4-39c5-4bb1-b20b-5cf85fcb3a98","type":"BoxZoomTool"},{"id":"a580262a-b2d0-4092-b9ff-dd147f71e03f","type":"SaveTool"},{"id":"204abd63-0150-443b-af80-1ae905a007f1","type":"ResetTool"},{"id":"91b2c5bb-ae06-43e5-ac0a-d5f042b04b4e","type":"HelpTool"}]},"id":"204a0717-6b6f-4288-8e26-48aaaf34f4b5","type":"Toolbar"},{"attributes":{"plot":{"id":"0f9b44ab-483e-4ad5-b35f-b16c78be0356","subtype":"Figure","type":"Plot"}},"id":"204abd63-0150-443b-af80-1ae905a007f1","type":"ResetTool"},{"attributes":{"plot":{"id":"0f9b44ab-483e-4ad5-b35f-b16c78be0356","subtype":"Figure","type":"Plot"}},"id":"91b2c5bb-ae06-43e5-ac0a-d5f042b04b4e","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"05e8c402-b18d-42da-8e10-bfe3bb7a0716","type":"BoxAnnotation"},{"attributes":{"axis_label":"log squared difference","axis_label_standoff":2,"axis_label_text_color":{"value":"#3c3c3c"},"axis_label_text_font":"Lucida Sans Unicode","axis_label_text_font_size":{"value":"13pt"},"axis_label_text_font_style":"normal","axis_line_color":{"value":null},"formatter":{"id":"a34d508d-6bf3-466f-9e4b-22266effec5e","type":"BasicTickFormatter"},"major_tick_line_color":{"value":null},"minor_tick_line_color":{"value":null},"plot":{"id":"0f9b44ab-483e-4ad5-b35f-b16c78be0356","subtype":"Figure","type":"Plot"},"ticker":{"id":"338a2f25-0572-4861-b976-f29c37aefd8e","type":"BasicTicker"}},"id":"a03351e7-009e-4a56-bada-a92ec54e67fc","type":"LinearAxis"},{"attributes":{"data_source":{"id":"fee6b6f9-9736-4741-b02c-90b3e11def80","type":"ColumnDataSource"},"glyph":{"id":"a02b98b4-aa42-47e1-9b59-7b852a7aad41","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"94e61f31-b927-49ca-86fa-eb3720cb05ff","type":"Circle"},"selection_glyph":null},"id":"5d4ed977-0517-4d56-aa38-3100ef614d85","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"2929fd9a-7171-4e25-8f23-a64abd6b32bf","type":"DataRange1d"},{"attributes":{},"id":"ee5ce14e-b235-447e-aa53-ad5f9353fca8","type":"LinearScale"},{"attributes":{},"id":"b2e0a294-238a-42ca-8a48-526b6b12753d","type":"ToolEvents"},{"attributes":{"axis_label":"log summed intensity ","axis_label_standoff":2,"axis_label_text_color":{"value":"#3c3c3c"},"axis_label_text_font":"Lucida Sans Unicode","axis_label_text_fo ...

# %%
x = np.random.normal

# %%
x = np.random.randn

# %%
bokeh.plotting.figure?

# %%
import matplotlib.pyplot as plt
matplotlib.matplotlib_fname()
# %matplotlib inline

# %%
plt.figure(figsize=(10,10))
plt.plot(data['I_tot'], data['square_diff'], 'o')
